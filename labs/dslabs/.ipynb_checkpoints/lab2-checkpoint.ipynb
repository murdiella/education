# %%
import numpy as np
import pandas as pd
import pickle   # сохранение модели
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error as mse, r2_score as r2
from IPython.display import Image

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv('newds.csv')
df.head()
# Out:
#    Unnamed: 0     Id  DistrictId  Rooms      Square  LifeSquare  \
# 0           0  11809          27    3.0  115.027311   32.781260
# 1           1   3013          22    1.0   39.832524   23.169223
# 2           2   8215           1    3.0   78.342215   47.671972
# 3           3   2352           1    1.0   40.409907   32.781260
# 4           4  13866          94    2.0   64.285067   38.562517
#
#    KitchenSquare  Floor  HouseFloor  HouseYear  ...  Ecology_2 Ecology_3  \
# 0           10.0      4        10.0       2014  ...          B         B
# 1            8.0      7         8.0       1966  ...          B         B
# 2           10.0      2        17.0       1988  ...          B         B
# 3            1.0     10        22.0       1977  ...          B         B
# 4            9.0     16        16.0       1972  ...          B         B
#
#   Social_1  Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# ...

# %%
feature_names = ['Rooms', 'Square', 'LifeSquare', 'KitchenSquare', 'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1',
            'Social_1', 'Social_3', 'Healthcare_1', 'Helthcare_2', 'Shops_1']
target_name = 'Price'
df = df[feature_names + [target_name]]
df.head()
# Out:
#    Rooms      Square  LifeSquare  KitchenSquare  Floor  HouseFloor  HouseYear  \
# 0    3.0  115.027311   32.781260           10.0      4        10.0       2014
# 1    1.0   39.832524   23.169223            8.0      7         8.0       1966
# 2    3.0   78.342215   47.671972           10.0      2        17.0       1988
# 3    1.0   40.409907   32.781260            1.0     10        22.0       1977
# 4    2.0   64.285067   38.562517            9.0     16        16.0       1972
#
#    Ecology_1  Social_1  Social_3  Healthcare_1  Helthcare_2  Shops_1  \
# 0   0.075424        11         2         900.0            0        3
# 1   0.118537        30         1        1183.0            1        3
# 2   0.025609        33         2         240.0            3        1
# 3   0.007122         1         2         900.0            0        1
# 4   0.282798        33         2         900.0            0        6
#
#            Price
# 0  305018.871089
# 1  177734.553407
# 2  282078.720850
# ...

# %%
feature_names_for_stand = df[feature_names].select_dtypes(include=['float32', 'float16', 'int64']).columns.tolist()
scaler = StandardScaler()
stand_features = scaler.fit_transform(df[feature_names_for_stand])

# %%
df[feature_names_for_stand] = pd.DataFrame(stand_features, columns=feature_names_for_stand)
df.to_csv('preparedds.csv', index=False, encoding='utf-8', sep=';')

# %%
X = df[feature_names]
y = df[target_name]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=42)

# %%
def evaluate_preds(true_values, pred_values, save=False):

    fig, ax = plt.subplots()
    textstr = ("R2:  " + str(round(r2(true_values, pred_values), 3)) + "\n" +
          "RMSE:  " + str(round(np.sqrt(mse(true_values, pred_values)), 3)) + "\n" +
          "MSE:  " + str(round(mse(true_values, pred_values), 3)))
    
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)    
    sns.scatterplot(x=pred_values, y=true_values)
    ax.plot([0, 500000], [0, 500000], linestyle='--', color='black')  # диагональ, где true_values = pred_values
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('True vs Predicted values')

    if save == True:
        plt.savefig(REPORTS_FILE_PATH + 'report.png')
    plt.show()

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_preds = lr_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
y_test_preds = lr_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)

# %%
dt_model = DecisionTreeRegressor(criterion='squared_error',
                                 max_depth=20,
                                 min_samples_leaf=30, 
                                 random_state=42)

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_leaf=30, random_state=42)

# %%
y_train_preds = dt_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
y_test_preds = dt_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)

# %%
rf_model = RandomForestRegressor(criterion='squared_error',
                                 max_depth=20, 
                                 min_samples_leaf=30,
                                 random_state=42,
                                 n_estimators=100
                                 )

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=30, random_state=42)

# %%
y_train_preds = rf_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
y_test_preds = rf_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)

# %%
gb_model = GradientBoostingRegressor(criterion='squared_error',
                                     max_depth=7,
                                     min_samples_leaf=10,
                                     random_state=42,
                                     n_estimators=100)

# %%
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(criterion='squared_error', max_depth=7,
#                           min_samples_leaf=10, random_state=42)

# %%
y_train_preds = gb_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
y_test_preds = gb_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)

# %%
ds = pd.read_csv('test2.csv')
lifesquare_med = ds['LifeSquare'].median()
ds['LifeSquare'] = ds['LifeSquare'].fillna(lifesquare_med)
Healthcare_1_med = ds['Healthcare_1'].median()
ds['Healthcare_1'] = ds['Healthcare_1'].fillna(Healthcare_1_med)
missing_num = ds.isnull().sum()
print(missing_num)
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# dtype: int64

# %%
gb_pred = gb_model.predict(ds.drop(columns=['DistrictId', 'Ecology_2', 'Ecology_3', 'Id', 'Shops_2', 'Social_2']))
gb = pd.DataFrame(gb_pred, columns=['predictions'])
gb.insert(0, 'Id', ds['Id'])
gb.to_csv('gb_pred2.csv', index=False)

# %%
lr_pred = lr_model.predict(ds.drop(columns=['DistrictId', 'Ecology_2', 'Ecology_3', 'Id', 'Shops_2', 'Social_2']))
pd.DataFrame(lr_pred, columns=['predictions']).to_csv('lr_pred2.csv', index=True)
# Out:
# array([-7804197.07739253, -8303088.05990365, -7888125.95640502, ...,
#        -7730111.11324821, -7527165.26828211, -7412629.40996301])

# %%
pickle.dump(lr_model, open('lr_model.pkl', 'wb'))
pickle.dump(dt_model, open('dt_model.pkl', 'wb'))
pickle.dump(rf_model, open('rf_model.pkl', 'wb'))
pickle.dump(gb_model, open('gb_model.pkl', 'wb'))

# %%
params = {'n_estimators': [50, 100, 200, 400],
          'max_depth': [3, 5, 7, 10]}
gs = GridSearchCV(gb_model, params,
                  scoring= 'r2', # метрика
                  cv=KFold(n_splits=5,   
    			  random_state=21,
                  shuffle=True),
                  n_jobs=-1
                  )

# %%
gs.fit(X_train, y_train)

# %%
gs.best_params_
